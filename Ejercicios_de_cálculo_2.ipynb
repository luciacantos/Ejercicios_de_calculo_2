# %% [markdown]
# 1. Calcula el límite indicado:

# %% [markdown]
# ![limite_1.png](attachment:limite_1.png)

# %%
f(n) = (n^3 + 2*n - 1)/(5*n^3 + n^2 - 2*n + 1)
limit(f(n), n=oo)
# Out:
# 1/5

# %% [markdown]
# 2. Calcula el límite indicado:

# %% [markdown]
# ![limite_2.png](attachment:limite_2.png)

# %%
f(n) = sqrt(n^2 - n) - sqrt(n^2 + 4*n)
limit(f(n), n=oo)
# Out:
# -5/2

# %% [markdown]
# 3. Calcula el límite indicado:

# %% [markdown]
# ![limite_3.png](attachment:limite_3.png)

# %%
f(n) = ln(1 + n + sqrt(n)) - ln(n)
limit(f(n), n=oo)
# Out:
# 0

# %% [markdown]
# 4. Calcula el límite indicado:

# %% [markdown]
# ![limite_4.png](attachment:limite_4.png)

# %%
f(n) = n^3/n^4
limit(f(n), n=oo)
# Out:
# 0

# %% [markdown]
# 5. Calcula el límite indicado:

# %% [markdown]
# ![limite_5.png](attachment:limite_5.png)

# %%
f(n) = ((n^3 - 2*n)/(n^3 + 3*n^2 - 2*n -1))^n
limit(f(n), n=oo)
# Out:
# e^(-3)

# %% [markdown]
# 6. Calcula la suma de la serie indicada:

# %% [markdown]
# ![sumatorio_6.png](attachment:sumatorio_6.png)

# %%
f(n) = (n + 2)/(n^3 - n)
sum(f(n), n, 2, oo)
# Out:
# 5/4

# %% [markdown]
# 7. Calcula la suma de la serie indicada:

# %% [markdown]
# ![sumatorio_7.png](attachment:sumatorio_7.png)

# %%
f(n) = 1/(n^3 - n)
sum(f(n), n, 2, oo)
# Out:
# 1/4

# %% [markdown]
# 8. Calcula la suma de la serie indicada:

# %% [markdown]
# ![sumatorio_8.png](attachment:sumatorio_8.png)

# %%
f(x,n) = (-1)^n * x^n
sum(f(x,n), x, 0, oo)
# Out:
# (-1)^n*sum(x^n, x, 0, +Infinity)

# %% [markdown]
# 9. Calcula la suma de la serie indicada:

# %% [markdown]
# ![sumatorio_9.png](attachment:sumatorio_9.png)

# %%
f(x,n) = (-1)^n * 4^n * x^(2*n) 
sum(f(x,n), x, 0, oo)
# Out:
# 4^n*(-1)^n*sum(x^(2*n), x, 0, +Infinity)

# %% [markdown]
# 10. Calcula la serie de Taylor en el orígen de la función indicada:

# %% [markdown]
# ![Taylor_10.png](attachment:Taylor_10.png)

# %%
f(x) = 1/(1 + x^2)
taylor(f(x), 0, 4)
# Out:
# 1/(x^2 + 1)

# %% [markdown]
# 11. Calcula la serie de Taylor en el orígen de la función indicada:

# %% [markdown]
# ![Taylor_11.png](attachment:Taylor_11.png)

# %%
g(x) = x*cos(x)
taylor(g(x), 0, 3)
# Out:
# x*cos(x)
